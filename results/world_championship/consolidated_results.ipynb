# %%
import pandas as pd
import os

# %%
df = pd.read_csv("world_championship_consolidated_results.csv")

# %%
df.columns
# Out:
# Index(['winner', 'event_name', 'country', 'score_a', 'player_b', 'player_a',
#        'championship_name', 'score_b', 'round_name'],
#       dtype='object')

# %%
df['round_name'].unique()
# Out:
# array(['1/8 Eliminations', '1/12 Eliminations', 'Gold Medal Match',
#        'Bronze Medal Match', 'Semifinals', 'Quarterfinals',
#        '1/48 Eliminations'], dtype=object)
